# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://downloads.apache.org/spark/spark-3.0.0-preview2/spark-3.0.0-preview2-bin-hadoop2.7.tgz
# !tar -xvf spark-3.0.0-preview2-bin-hadoop2.7.tgz
# !pip install -q findspark
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-preview2-bin-hadoop2.7"
import findspark
findspark.init()

# Importing the libraries required 
from pyspark.sql import Row
from pyspark.sql.types import *
from pyspark.sql.functions import sum
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
sc= spark.sparkContext
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlb

# %%
data = spark.read.csv('/content/CC_data.csv', header = 'true', inferSchema='true')
#data_new = data.withColumnRenamed("Male","Gender").printSchema()
type(data)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
data.show(5)
# Out:
# +------+-----+-----+-------+------------+--------------+---------+-------------+------------+--------+-----------+--------------+-------+-------+------+--------+
# |Gender|  Age| Debt|Married|BankCustomer|EducationLevel|Ethnicity|YearsEmployed|PriorDefault|Employed|CreditScore|DriversLicense|Citizen|ZipCode|Income|Approved|
# +------+-----+-----+-------+------------+--------------+---------+-------------+------------+--------+-----------+--------------+-------+-------+------+--------+
# |     b|30.83|  0.0|      u|           g|             w|        v|         1.25|           t|       t|          1|             f|      g|    202|     0|       +|
# |     a|58.67| 4.46|      u|           g|             q|        h|         3.04|           t|       t|          6|             f|      g|     43|   560|       +|
# |     a| 24.5|  0.5|      u|           g|             q|        h|          1.5|           t|       f|          0|             f|      g|    280|   824|       +|
# |     b|27.83| 1.54|      u|           g|             w|        v|         3.75|           t|       t|          5|             t|      g|    100|     3|       +|
# |     b|20.17|5.625|      u|           g|             w|        v|         1.71|           t|       f|          0|             f|      s|    120|     0|       +|
# +------+-----+-----+-------+------------+--------------+---------+-------------+------------+--------+-----------+--------------+-------+-------+------+--------+
# only showing top 5 rows

# %%
class_frequency = data.groupBy("Approved").count()
class_frequency.show()
# Out:
# +--------+-----+
# |Approved|count|
# +--------+-----+
# |       +|  307|
# |       -|  383|
# +--------+-----+

# %%
data2 = data.toPandas()
data2
# Out:
#     Gender    Age    Debt Married  ... Citizen ZipCode Income  Approved
# 0        b  30.83   0.000       u  ...       g     202      0         +
# 1        a  58.67   4.460       u  ...       g      43    560         +
# 2        a   24.5   0.500       u  ...       g     280    824         +
# 3        b  27.83   1.540       u  ...       g     100      3         +
# 4        b  20.17   5.625       u  ...       s     120      0         +
# ..     ...    ...     ...     ...  ...     ...     ...    ...       ...
# 685      b  21.08  10.085       y  ...       g     260      0         -
# 686      a  22.67   0.750       u  ...       g     200    394         -
# 687      a  25.25  13.500       y  ...       g     200      1         -
# 688      b  17.92   0.205       u  ...       g     280    750         -
# 689      b     35   3.375       u  ...       g       0      0         -
#
# [690 rows x 16 columns]

# %%
# Replace "?" with NaN
data2.replace('?', np.NaN, inplace = True)
# Convert Age to numeric
data2["Age"] = pd.to_numeric(data2["Age"])
# CC_data2 = CC_data[:,:]
data3 = data2.copy()

# %%
data3.tail(5)
# Out:
#     Gender    Age    Debt Married  ... Citizen ZipCode Income  Approved
# 685      b  21.08  10.085       y  ...       g     260      0         -
# 686      a  22.67   0.750       u  ...       g     200    394         -
# 687      a  25.25  13.500       y  ...       g     200      1         -
# 688      b  17.92   0.205       u  ...       g     280    750         -
# 689      b  35.00   3.375       u  ...       g       0      0         -
#
# [5 rows x 16 columns]

# %%
data3.isnull().sum()
# Out:
# Gender            12
# Age               12
# Debt               0
# Married            6
# BankCustomer       6
# EducationLevel     9
# Ethnicity          9
# YearsEmployed      0
# PriorDefault       0
# Employed           0
# CreditScore        0
# DriversLicense     0
# Citizen            0
# ZipCode           13
# Income             0
# Approved           0
# dtype: int64

# %% [markdown]
# We still having some missing values to deal with. Gender, Age and ZipCode have some missing values

# %%
# Impute the missing values with mean imputation
data3.fillna(data3.mean(), inplace=True)

# Count the number of NaNs in the dataset to verify
pd.isna(data3).sum()
data3.tail(18)
# Out:
#     Gender    Age    Debt Married  ... Citizen ZipCode Income  Approved
# 672      a  50.25   0.835       u  ...       g     240    117         -
# 673    NaN  29.50   2.000       y  ...       g     256     17         -
# 674      a  37.33   2.500       u  ...       g     260    246         -
# 675      a  41.58   1.040       u  ...       g     240    237         -
# 676      a  30.58  10.665       u  ...       g     129      3         -
# 677      b  19.42   7.250       u  ...       g     100      1         -
# 678      a  17.92  10.210       u  ...       g       0     50         -
# 679      a  20.08   1.250       u  ...       g       0      0         -
# 680      b  19.50   0.290       u  ...       g     280    364         -
# 681      b  27.83   1.000       y  ...       g     176    537         -
# 682      b  17.08   3.290       u  ...       g     140      2         -
# 683      b  36.42   0.750       y  ...       g     240      3         -
# 684      b  40.58   3.290       u  ...       s     400      0         -
# 685      b  21.08  10.085       y  ...       g     260      0         -
# 686      a  22.67   0.750       u  ...       g     200    394         -
# 687      a  25.25  13.500       y  ...       g     200      1         -
# 688      b  17.92   0.205       u  ...       g     280    750         -
# 689      b  35.00   3.375       u  ...       g       0      0         -
#
# [18 rows x 16 columns]

# %%
# Iterate over each column of data3
for col in data3:
    # Check if the column is of object type
    if data3[col].dtype == 'object':
        # Impute with the most frequent value
        data3 = data3.fillna(data3[col].value_counts().index[0])
        

# Count the number of NaNs in the dataset and print the counts to verify
pd.isna(data3).sum()
# Out:
# Gender            0
# Age               0
# Debt              0
# Married           0
# BankCustomer      0
# EducationLevel    0
# Ethnicity         0
# YearsEmployed     0
# PriorDefault      0
# Employed          0
# CreditScore       0
# DriversLicense    0
# Citizen           0
# ZipCode           0
# Income            0
# Approved          0
# dtype: int64

# %% [markdown]
# **CORRELATION MATRIX FOR PREDICTORS HAVING NUMERIC DATATYPE** - We consider the most relevant predictors that have a numeric datatype and hence zipcode is excluded.

# %%
#correlation matrix
import seaborn as sns
corrmat = data3.corr()
corrmat.style.background_gradient(cmap='Accent')
# Out:
# <style  type="text/css" >
#     #T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col0 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col1 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col2 {
#             background-color:  #fdc086;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col3 {
#             background-color:  #beaed4;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col4 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col0 {
#             background-color:  #beaed4;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col1 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col2 {
#             background-color:  #fdc086;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col3 {
#             background-color:  #beaed4;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col4 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col0 {
#             background-color:  #ffff99;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col1 {
#             background-color:  #beaed4;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col2 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col3 {
#             background-color:  #fdc086;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col4 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col0 {
#             background-color:  #beaed4;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col1 {
#             background-color:  #beaed4;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col2 {
#             background-color:  #fdc086;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col3 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col4 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col0 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col1 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col2 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col3 {
#             background-color:  #7fc97f;
#             color:  #000000;
#         }    #T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col4 {
#             background-color:  #666666;
#             color:  #f1f1f1;
#         }</style><table id="T_bd7ec860_7610_11ea_b996_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >Debt</th>        <th class="col_heading level0 col2" >YearsEmployed</th>        <th class="col_heading level0 col3" >CreditScore</th>        <th class="col_heading level0 col4" >Income</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bd7ec860_7610_11ea_b996_0242ac1c0002level0_row0" class="row_heading level0 row0" >Age</th>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col1" class="data row0 col1" >0.201316</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col2" class="data row0 col2" >0.392787</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col3" class="data row0 col3" >0.185575</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row0_col4" class="data row0 col4" >0.018539</td>
#             </tr>
#             <tr>
#                         <th id="T_bd7ec860_7610_11ea_b996_0242ac1c0002level0_row1" class="row_heading level0 row1" >Debt</th>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col0" class="data row1 col0" >0.201316</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col2" class="data row1 col2" >0.298902</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col3" class="data row1 col3" >0.271207</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row1_col4" class="data row1 col4" >0.123121</td>
#             </tr>
#             <tr>
#                         <th id="T_bd7ec860_7610_11ea_b996_0242ac1c0002level0_row2" class="row_heading level0 row2" >YearsEmployed</th>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col0" class="data row2 col0" >0.392787</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col1" class="data row2 col1" >0.298902</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col3" class="data row2 col3" >0.322330</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row2_col4" class="data row2 col4" >0.051345</td>
#             </tr>
#             <tr>
#                         <th id="T_bd7ec860_7610_11ea_b996_0242ac1c0002level0_row3" class="row_heading level0 row3" >CreditScore</th>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col0" class="data row3 col0" >0.185575</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col1" class="data row3 col1" >0.271207</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col2" class="data row3 col2" >0.322330</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row3_col4" class="data row3 col4" >0.063692</td>
#             </tr>
#             <tr>
#                         <th id="T_bd7ec860_7610_11ea_b996_0242ac1c0002level0_row4" class="row_heading level0 row4" >Income</th>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col0" class="data row4 col0" >0.018539</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col1" class="data row4 col1" >0.123121</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col2" class="data row4 col2" >0.051345</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col3" class="data row4 col3" >0.063692</td>
#                         <td id="T_bd7ec860_7610_11ea_b996_0242ac1c0002row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# There seems to be a close relationship between the below pair of predictor variables -
# 1. YearsEmployed and Age
# 2. YearsEmployed and Credit Score
# 3. Years Employed and Debt

# %% [markdown]
# **FINDING RELATIONSHIP BETWEEN PREDICTOR VARIABLE AND RESPONSE VARIABLE**
#
# We used the crosstab  function from pandas package that explains which predictor is likely to contribute to the credit card approval prediction.

# %%
def percConvert(ser):
  return ser/float(ser[-1])*100
  pd.crosstab(data3["EducationLevel"],data3["Approved"],margins=True).apply(percConvert, axis=1)

# %% [markdown]
# 1) Effect of Education level on Credit Card approval

# %%
pd.crosstab(data3["EducationLevel"],data3["Approved"],margins=True).apply(percConvert, axis=1)

# %% [markdown]
# 2) Effect of Gender on Credit Card approvals

# %%
pd.crosstab(data3["Gender"],data3["Approved"],margins=True).apply(percConvert, axis=1)

# %% [markdown]
# 3)

# %%
pd.crosstab(data3["CreditScore"],data3["Approved"],margins=True).apply(percConvert, axis=1)
#pd.crosstab(data3["Debt"],data3["Approved"],margins=True).apply(percConvert, axis=1)
#pd.crosstab(data3["Married"],data3["Approved"],margins=True).apply(percConvert, axis=1)
#pd.crosstab(data3["BankCustomer"],data3["Approved"],margins=True).apply(percConvert, axis=1)
#pd.crosstab(data3["Ethnicity"],data3["Approved"],margins=True).apply(percConvert, axis=1)
#pd.crosstab(data3["YearsEmployed"],data3["Approved"],margins=True).apply(percConvert, axis=1)

# %%
pd.crosstab(data3["PriorDefault"],data3["Approved"],margins=True).apply(percConvert, axis=1) #In Percentage
# Out:
# Approved              +          -    All
# PriorDefault
# f              6.990881  93.009119  100.0
# t             78.670360  21.329640  100.0
# All           44.492754  55.507246  100.0

# %% [markdown]
# **COVERTING ALL ATTRIBUTES INTO A NUMERICAL VALUE BY ASSIGNING LABELS**

# %%
#label_data = data3
le = LabelEncoder()
# # Looping for each object type column
# Using label encoder to convert into numeric types
for col in label_data:
    if label_data[col].dtypes=='object':
        label_data[col]=le.fit_transform(label_data[col])

# %%
label_data.head(5)
# Out:
#    Gender    Age   Debt  Married  ...  Citizen  ZipCode  Income  Approved
# 0       1  30.83  0.000        2  ...        0       42       0         0
# 1       0  58.67  4.460        2  ...        0      118     560         0
# 2       0  24.50  0.500        2  ...        0       74     824         0
# 3       1  27.83  1.540        2  ...        0        1       3         0
# 4       1  20.17  5.625        2  ...        2        8       0         0
#
# [5 rows x 16 columns]
